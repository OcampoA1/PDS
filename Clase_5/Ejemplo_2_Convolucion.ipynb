# %% [markdown]
# # Ejemplo 2. Convolución de Señales.

# %%
# Importar las librerias necesarias
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $x(n)=[\overrightarrow{4}, 3, 2]$
#
# $h(n)=[10, \overrightarrow{20}, 10]$

# %%
# Sabiendo que h(n) tiene el cero en el 20 y x(n) lo tiene en el primer elemento:
# N1=0 y N2=-1. M1=2, M2=1. N1+N2 <= n <= M1+M2
# El rango debe ser desde [-1,3]
n = np.arange(-1,4)
h = np.array([10, 20, 10])  # h(n)
x = np.array([4, 3, 2])     # x(n)
y = np.convolve(h, x)       # Convolución de las señales y(n)

# %%
# Grafica de la convolución
plt.figure()
plt.stem(n, y)
plt.xlabel('Numero de muestras')
plt.ylabel('Amplitud')
plt.grid()
plt.show()

# %% [markdown]
# Otro ejemplo de convolución:
#
# $j(n)=[\overrightarrow{-2}, 0, 1, -1, 3]$
#
# $k(n)=[\overrightarrow{1}, 2, 0, -1]$

# %%
# En este caso los ceros de ambos arreglos están en el primer elemento
# entonces se sabe que N1=N2=0 y M1=4, M2=3
# El rango es entonces: 0 <= n <= 7
n2 =np.arange(0, 8)
j = np.array([-2, 0, 1, -1, 3])
k = np.array([1, 2, 0, -1])
z = np.convolve(j, k)

# %%
# Grafica de la convolución
plt.figure()
plt.stem(n2, z)
plt.xlabel('Numero de muestras')
plt.ylabel('Amplitud')
plt.grid()
plt.show()

# %% [markdown]
# # Ejemplos propios

# %% [markdown]
# $x(n)=[\overrightarrow{6}, 10, 9, 7]$
#
# $h(n)=[1, \overrightarrow{2}, 10, 6, 8, 9]$

# %%
import numpy as np
import matplotlib.pyplot as plt
# En este caso los ceros de ambos arreglos están en el primer elemento
# entonces se sabe que N1=0, N2=-1 y M1=3, M2=4
# El rango es entonces: -1 <= n <= 7
n =np.arange(-1, 8)
x = np.array([6, 10, 9, 7])
h = np.array([1, 2, 10, 6, 8, 9])
z = np.convolve(x, h)
# Grafica de la convolución
plt.figure()
plt.stem(n, z)
plt.xlabel('Numero de muestras')
plt.ylabel('Amplitud')
plt.grid()
plt.show()

# %% [markdown]
# $x(n)=[1,3,4,\overrightarrow{6}, 6]$
#
# $h(n)=[5,6, \overrightarrow{2}, 5, 7]$

# %%
import numpy as np
import matplotlib.pyplot as plt
# En este caso los ceros de ambos arreglos están en el primer elemento
# entonces se sabe que N1=-3, N2=-2 y M1=1, M2=2
# El rango es entonces: -5 <= n <= 3
n =np.arange(-5, 4)
x = np.array([1, 3, 4, 6, 6])
h = np.array([5, 6, 2, 5, 7])
z = np.convolve(x, h)
# Grafica de la convolución
plt.figure()
plt.stem(n, z)
plt.xlabel('Numero de muestras')
plt.ylabel('Amplitud')
plt.grid()
plt.show()
